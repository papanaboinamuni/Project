# %%
#Import the required libraries
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation

# %% [markdown]
# **Task1:**

# %%
#Read the csv file in the jupiter notebook
Data = pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")
Data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
#Displaying  the number of rows and columns in the dataset.
Data.shape
# Out:
# (4803, 20)

# %%
# Displaying the title and genres of the first 50 movies from the dataset.
Data[["title","genres"]].head(50)
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# **Task2:**

# %%
# Identify the columns that have null values.
Data.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# check the data type
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# homepage
mode_value = Data["homepage"].mode()[0]

# Fill missing categorical object data type values with the mode value
Data["homepage"].fillna(value=mode_value, inplace=True)

# %%
# tagline
mode_value = Data["tagline"].mode()[0]

# Fill missing categorical object data type values with the mode value
Data["tagline"].fillna(value=mode_value, inplace=True)

# %%
# Overview
mode_value = Data["overview"].mode()[0]

# Fill missing categorical object data type values with the mode value
Data["overview"].fillna(value=mode_value, inplace=True)

# %%
# release_data
mode_value = Data["release_date"].mode()[0]

# Fill missing categorical object data type values with the mode value
Data["release_date"].fillna(value=mode_value, inplace=True)

# %%
# runtime
mean_value = Data["runtime"].mean()

# Fill missing Numerical object data type values with the mode value
Data["runtime"].fillna(value=mean_value, inplace=True)

# %%
# Again check the null values are present or not
Data.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# **Task3:**

# %%
import ast

# %%
Data['genres'] = Data['genres'].apply(ast.literal_eval)

Data['categories'] = Data['genres'].apply(lambda x: ', '.join([genre['name'] for genre in x]))

# %%
#Display the movie categories that have a budget greater than $220,000
filtered_Budget = Data[Data['budget'] > 220000]
filtered_Budget[['title','categories','budget']]
# Out:
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4680                               Malevolence
# 4682                              Super Hybrid
# 4720                     The Birth of a Nation
# 4758                                The Signal
# 4770                       Mutual Appreciation
#
#                                        categories     budget
# 0     Action, Adventure, Fantasy, Science Fiction  237000000
# 1                      Adventure, Fantasy, Action  300000000
# 2                        Action, Adventure, Crime  245000000
# 3                  Action, Crime, Drama, Thriller  250000000
# 4              Action, Adventure, Science Fiction  260000000
# ...

# %% [markdown]
# **Task4:**

# %%
#Display the movies category where the revenue is greater than $961,000,000.
filtered_Revenue = Data[Data['revenue'] > 961000000]
filtered_Revenue[['title','categories','revenue']]
# Out:
#                                              title  \
# 0                                           Avatar
# 3                            The Dark Knight Rises
# 7                          Avengers: Age of Ultron
# 12      Pirates of the Caribbean: Dead Man's Chest
# 16                                    The Avengers
# 17     Pirates of the Caribbean: On Stranger Tides
# 25                                         Titanic
# 26                      Captain America: Civil War
# 28                                  Jurassic World
# 29                                         Skyfall
# 31                                      Iron Man 3
# 32                             Alice in Wonderland
# 36                 Transformers: Age of Extinction
# 42                                     Toy Story 3
# 44                                       Furious 7
# 52                  Transformers: Dark of the Moon
# 65                                 The Dark Knight
# ...

# %% [markdown]
# **Task5:**

# %%
# Drop the rows which are having the 0 value present in the budget and revenue columns
Drop_rows = Data[(Data['budget'] != 0) & (Data['revenue'] != 0)]
Drop_rows
# Out:
#          budget                                             genres  \
# 0     237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1     300000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2     245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3     250000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4     260000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...         ...                                                ...
# 4773      27000                     [{'id': 35, 'name': 'Comedy'}]
# 4788      12000  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4792      20000  [{'id': 80, 'name': 'Crime'}, {'id': 27, 'name...
# 4796       7000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 4798     220000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# **Task6:**

# %% [markdown]
# #Sort the revenue data descending order
# revenue_Data = Drop_rows.sort_values(by='revenue', ascending=False)

# %%
# pick Top 10 movies with high revenue
revenue_Data[['title','revenue']].head(10)
# Out:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
#Sort the budget data ascending order
budget_Data =Drop_rows.sort_values(by='budget', ascending=True)

# %%
#Pick the top 10 movies with least budget
budget_Data[['title','budget']].head(10)
# Out:
#                    title  budget
# 4238        Modern Times       1
# 3611  A Farewell to Arms       4
# 3372        Split Second       7
# 3419        Bran Nue Dae       7
# 4608        The Prophecy       8
# 3131   Of Horses and Men      10
# 3137           Nurse 3-D      10
# 2933            F.I.S.T.      11
# 1912      Angela's Ashes      25
# 1771      The 51st State      28

# %% [markdown]
# **Task7:**

# %%
# Display the popularity and budget has related as correlated or fully or uncorrelated
correlation_matrix = Data[['popularity', 'budget']].corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='PuRd', linewidths=.5)
plt.show()

# %% [markdown]
# **Interpretation:**
#
#  The popularities of movies and movie budget
# are related with shows correlation coefficient value of 0.51 between
#  two columns, this indicates a positive linear correlation between the
# two variables. A correlation coefficient of 0.51 is greater than 0,
#  which suggests a moderately positive relationship between the two columns.

# %% [markdown]
# **Task8:**

# %%
# # Initialize an empty dictionary to store production company names and their counts
production_counts = {}

# Iterate over each row in the DataFrame
for row in Data.itertuples(index=False):
    # Iterate over each production company in the row
    for company in row.production_companies:
        # Extract the production company name
        company_name = company['name']
        
        # Increment the count for the production company
        if company_name in production_counts:
            production_counts[company_name] += 1
        else:
            production_counts[company_name] = 1

# Create a new DataFrame to store the production company names and their counts
production_Data = pd.DataFrame({'Production Company': list(production_counts.keys()), 'Count': list(production_counts.values())})

# Sort the DataFrame by count in descending order
production_Data = production_df.sort_values('Count', ascending=False)
production_Data
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    319
# 52                        Universal Pictures    311
# 38                        Paramount Pictures    285
# 1     Twentieth Century Fox Film Corporation    222
# 7                          Columbia Pictures    201
# ...                                      ...    ...
# 4326                  Perlapartment Pictures      1
# 4327                                Gobsmack      1
# 4328                   H&H Creative Ventures      1
# 4540                        Lowland Pictures      1
# 5016                        lucky crow films      1
#
# [5017 rows x 2 columns]

# %% [markdown]
# **Task9:**

# %%
# Select the top 25 production companies in descending order
production_df = production_df.sort_values('Count', ascending=False)
production_df.head(25)
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    319
# 52                        Universal Pictures    311
# 38                        Paramount Pictures    285
# 1     Twentieth Century Fox Film Corporation    222
# 7                          Columbia Pictures    201
# 46                           New Line Cinema    165
# 49                 Metro-Goldwyn-Mayer (MGM)    122
# 200                      Touchstone Pictures    118
# 4                       Walt Disney Pictures    114
# 54                          Relativity Media    102
# 257            Columbia Pictures Corporation     96
# 391                            Miramax Films     94
# 112                Village Roadshow Pictures     81
# 80                            DreamWorks SKG     79
# 532                           United Artists     75
# 370                                   Canal+     75
# 296                      Regency Enterprises     69
# ...

# %% [markdown]
# **Task:10**

# %%
# Sord the data in descending order based on revenue and filter the top  500 movies
sorted_Data=Drop_rows.sort_values('revenue',ascending=False)
sorted_Data.head(500)
# Out:
#          budget                                             genres  \
# 0     237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 25    200000000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 16    220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 28    150000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 44    190000000                     [{'id': 28, 'name': 'Action'}]
# ...         ...                                                ...
# 397    85000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 1744   30000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 698    70000000  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 717    60000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 714    65000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %%
#Define a function for central tendency 
def info_of_numerical(col):
    print(f"The mean of the {col} is {sorted_Data[col].mean()}")
    print(f"The median of the {col} is {sorted_Data[col].median()}")
    print(f"The mode of the {col} is {sorted_Data[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {sorted_Data[col].std()}")
    print(f"Number of missing values in the {col} is {sorted_Data[col].isnull().sum()}")

# %%
# find the measure of central Tendency for budget column
info_of_numerical("budget")
# Out:
# The mean of the budget is 40654444.774233505
# The median of the budget is 25000000.0
# The mode of the budget is 20000000
# The standard deviation of the budget is 44396741.80266044
# Number of missing values in the budget is 0

# %%
# Visualize the boxplot for outlier analysis
plt.figure(figsize=(10,5))
plt.boxplot(sorted_Data['budget'],vert=False,patch_artist=True,boxprops=dict(facecolor='green'))
plt.title('Budget Box Plot')
plt.show()

# %% [markdown]
# **Interpretation:**
#
#     The central tendency of the budget column shows the average of 40654444, median value of 25000000 and mode value shows the 20000000. And visualise purpose box plot is used, in that I can observe that outliers are present in the upperfence and the mean value is greater median value so it’s a right skewness.

# %%
# find the measure of central Tendency for revenue column
info_of_numerical("revenue")
# Out:
# The mean of the revenue is 121242957.26138124
# The median of the revenue is 55184721.0
# The mode of the revenue is 8000000
# The standard deviation of the revenue is 186302864.01426587
# Number of missing values in the revenue is 0

# %%
# Visualize the boxplot for outlier analysis
plt.figure(figsize=(7,5))
plt.boxplot(sorted_Data['revenue'],vert=False,patch_artist=True,boxprops=dict(facecolor='blue'))
plt.title('Revenue Box Plot')
plt.show()

# %% [markdown]
# **Interpretation:**
#
# For the revenue column show the average of 121242957, median value of 55184721 and mode value is 8000000. To visualisation, box plot is used, I observed that outliers are present in the upperfence and the mean value is  greater than median value , so it is also shows the right skewness.

# %%
# find the measure of central Tendency for revenue column
info_of_numerical("runtime")

# %%
# Visualize the boxplot for outlier analysis
plt.figure(figsize=(7,3))
plt.boxplot(sorted_Data['runtime'],vert=False,patch_artist=True,boxprops=dict(facecolor='blue'))
plt.title('Runtime Box Plot')
plt.show()

# %% [markdown]
# **Interpretation:**
#
# For the runtime column show the average of 110 , median value is 107 and mode is 100. To visualisation, boxplot is used , I Observed that outliers are present in both the upper and lower fence in runtime boxplot. It is nearly equal or not, it shows right skewness or  no skewness.

# %% [markdown]
# **Task:11**

# %%
# Average runtime 
avg_runtime=sorted_Data['runtime'].mean()
avg_runtime
# Out:
# 110.72437287085785

# %%
# filter the data above the average rutime
above=sorted_Data[sorted_Data['runtime']>avg_runtime]
above
# Out:
#          budget                                             genres  \
# 0     237000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 25    200000000  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 16    220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 28    150000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 44    190000000                     [{'id': 28, 'name': 'Action'}]
# ...         ...                                                ...
# 4065    2100000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2874   12000000  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 1912         25                      [{'id': 18, 'name': 'Drama'}]
# 1655   23000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2933         11  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %%
# Display the names of the movies along with their run time for those movies that have average runtime
movies=above[['title','runtime']]
movies
# Out:
#                 title  runtime
# 0              Avatar    162.0
# 25            Titanic    194.0
# 16       The Avengers    143.0
# 28     Jurassic World    124.0
# 44          Furious 7    137.0
# ...               ...      ...
# 4065       Mi America    126.0
# 2874       In the Cut    119.0
# 1912   Angela's Ashes    145.0
# 1655  Chasing Liberty    111.0
# 2933         F.I.S.T.    145.0
#
# [1362 rows x 2 columns]
